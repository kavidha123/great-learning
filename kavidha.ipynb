# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import zipfile for extraction
import zipfile

# Set the path to your new zip file in Google Drive
zip_path = "/content/drive/MyDrive/UTSW-Glioma.zip"

# Set extraction folder
extract_path = "/content/UTSW-Glioma"

# Extract the zip file
with zipfile.ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(extract_path)

print("UTSWGlioma extracted successfully")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_13382/1212957090.py in <cell line: 0>()
#      10 # Extract the zip file
#      11 with zipfile.ZipFile(zip_path, "r") as zip_ref:
# ---> 12     zip_ref.extractall(extract_path)
#      13
#      14 print("UTSWGlioma extracted successfully")
#
# /usr/lib/python3.12/zipfile/__init__.py in extractall(self, path, members, pwd)
#    1768
#    1769         for zipinfo in members:
# -> 1770             self._extract_member(zipinfo, path, pwd)
#    1771
#    1772     @classmethod
#
# /usr/lib/python3.12/zipfile/__init__.py in _extract_member(self, member, targetpath, pwd)
#    1826         with self.open(member, pwd=pwd) as source, \
#    1827              open(targetpath, "wb") as target:
# -> 1828             shutil.copyfileobj(source, target)
#    1829
#    1830         return targetpath
#
# /usr/lib/python3.12/shutil.py in copyfileobj(fsrc, fdst, length)
#     201     fsrc_read = fsrc.read
#     202     fdst_write = fdst.write
# --> 203     while buf := fsrc_read(length):
#     204         fdst_write(buf)
#     205
#
# /usr/lib/python3.12/zipfile/__init__.py in read(self, n)
#    1006         self._offset = 0
#    1007         while n > 0 and not self._eof:
# -> 1008             data = self._read1(n)
#    1009             if n < len(data):
#    1010                 self._readbuffer = data
#
# /usr/lib/python3.12/zipfile/__init__.py in _read1(self, n)
#    1074             data = self._decompressor.unconsumed_tail
#    1075             if n > len(data):
# -> 1076                 data += self._read2(n - len(data))
#    1077         else:
#    1078             data = self._read2(n)
#
# /usr/lib/python3.12/zipfile/__init__.py in _read2(self, n)
#    1106         n = min(n, self._compress_left)
#    1107
# -> 1108         data = self._fileobj.read(n)
#    1109         self._compress_left -= len(data)
#    1110         if not data:
#
# /usr/lib/python3.12/zipfile/__init__.py in read(self, n)
#     825                         "Close the writing handle before trying to read.")
#     826             self._file.seek(self._pos)
# --> 827             data = self._file.read(n)
#     828             self._pos = self._file.tell()
#     829             return data
#
# KeyboardInterrupt:
